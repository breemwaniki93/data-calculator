# %%
# Basic Data Calculator - Milestone Project
# Display welcome message
print("=" * 50)
print("Welcome to the Data Calculator!")
print("=" * 50)
# Out:
# ==================================================
# Welcome to the Data Calculator!
# ==================================================

# %%
# Get user input for two numbers
num1 = float(input("Enter the first number: "))
num2 = float(input("Enter the second number: "))
operation = input("Choose an operation (+, -, *, /): ")
# Out:
# Enter the first number:  6
# Enter the second number:  7
# Choose an operation (+, -, *, /):  *

# %%
# Perform the calculation based on user's choice
if operation == "+":
    result = num1 + num2
    
elif operation == "-":
    result = num1 - num2
    
elif operation == "*":
    result = num1 * num2
    
elif operation == "/":
    # Check for division by zero
    if num2 != 0:
        result = num1 / num2
    else:
        print("Error: Cannot divide by zero!")
        result = None  # No valid result
        
else:
    print("Invalid operation! Please choose +, -, *, or /")
    result = None

# %%
# Print the result (if valid)
if result is not None:
    print(f"The result of {num1} {operation} {num2} is {result}")
# Out:
# The result of 6.0 * 7.0 is 42.0

# %%
print("=" * 50)
print("Thank you for using the Data Calculator!")
print("=" * 50)
# Out:
# ==================================================
# Thank you for using the Data Calculator!
# ==================================================
